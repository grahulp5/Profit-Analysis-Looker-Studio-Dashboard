# %%
import pandas as pd
import numpy as np

# %%
budget=pd.read_csv('/content/budget.csv')
budget.head(2)
# Out:
#         Date         IT Dep.           CostElement Country Budget
# 0  1/01/2020  Administration  Employee Performance     USA     87
# 1  1/02/2020  Administration  Employee Performance     USA     87

# %%
forecast=pd.read_csv('/content/forecast.csv')
forecast.head(2)
# Out:
#         Date         IT Dep.     CostElement Country Forecast
# 0  1/07/2020  Administration  Administrative     USA  -21,785
# 1  1/08/2020  Administration  Administrative     USA  -21,785

# %%
merged_file = pd.merge(budget, forecast, on=['Date', 'IT Dep.', 'CostElement', 'Country'], how='inner')
merged_file.head(2)
# Out:
#         Date         IT Dep.           CostElement Country Budget Forecast
# 0  1/02/2020  Administration  Employee Performance     USA     87       27
# 1  1/03/2020  Administration  Employee Performance     USA     87      150

# %%
#saving file
merged_file.to_csv('merged_data.csv', index=False)
